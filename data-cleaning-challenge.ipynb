# %%
# libraries
import pandas as pd

# Present Working Directory | Get Current Working Directory
import os
pwd = os.getcwd()
pwd
# Out:
# 'C:\\Users\\jisbe\\Portfolio_Projects\\Projects\\Shashank - Data Cleaning CHALLENGE'

# %%
# import csv into jupyter notebooks
data_import = pd.read_csv(pwd + '\\data_cleaning_challenge.csv')
data_import
# Out:
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 1                     NaN               NaN                NaN     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque  Unnamed: 9 Unnamed: 10
# 0         NaN          NaN     NaN     NaN     NaN         NaN         NaN
# 1         NaN          NaN     NaN     NaN     NaN         NaN         NaN
# 2      Speed2  Electricity  Effort  Weight  Torque         NaN         NaN
# 3         863          599     680     442     982         NaN         NaN
# 4         613          241     249     758     639         NaN         NaN
# ...       ...          ...     ...     ...     ...         ...         ...
# 76372     977          680     500     395     863         NaN         NaN
# 76373     374          448     407     185     439         NaN         NaN
# 76374      53          982     217     963     502         NaN         NaN
# 76375     630          239     561     142     909         NaN         NaN
# 76376       -            -     847     583     407         NaN         NaN
#
# [76377 rows x 11 columns]

# %%
# change header names to Row Type, Iter Number, Power1, etc. 
# this was a manual manipulatin to the CSV

# %%
# drop empty columns - using 'columns = []', you can drop multiple columns with a list
# create a new variable for a new copy before dropping, so that the existing data set can remain as the source
drop_extra = data_import.drop(columns = ['Unnamed: 9', 'Unnamed: 10'])
drop_extra
# Out:
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 1                     NaN               NaN                NaN     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque
# 0         NaN          NaN     NaN     NaN     NaN
# 1         NaN          NaN     NaN     NaN     NaN
# 2      Speed2  Electricity  Effort  Weight  Torque
# 3         863          599     680     442     982
# 4         613          241     249     758     639
# ...       ...          ...     ...     ...     ...
# 76372     977          680     500     395     863
# 76373     374          448     407     185     439
# 76374      53          982     217     963     502
# 76375     630          239     561     142     909
# 76376       -            -     847     583     407
#
# [76377 rows x 9 columns]

# %%
# drop NaN values - rows drop from, 76377 to 58397
drop_nans = drop_extra[drop_extra['Row Type'].notna()]
drop_nans
# Out:
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# 5                    Iter                 3                365     126
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque
# 0         NaN          NaN     NaN     NaN     NaN
# 2      Speed2  Electricity  Effort  Weight  Torque
# 3         863          599     680     442     982
# 4         613          241     249     758     639
# 5         825          407     855     164      86
# ...       ...          ...     ...     ...     ...
# 76372     977          680     500     395     863
# 76373     374          448     407     185     439
# 76374      53          982     217     963     502
# 76375     630          239     561     142     909
# 76376       -            -     847     583     407
#
# [58397 rows x 9 columns]

# %%
# create a for loop that searches for 'first name' and then it copies all data until it reaches 'first name' again
# create a list
column_values = []
counter = 0

for i in drop_nans['Row Type']:
    if 'first name' in i:
        # print(i) used for error handling
        counter += 1
    column_values.append(counter)

# %%
# we now have a list for our column values
# we want to make this a new column in our dataset
iter_cols = drop_nans
iter_cols['Iteration'] = column_values
iter_cols
# Out:
# <ipython-input-50-319d803edcc9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iter_cols['Iteration'] = column_values
#                  Row Type       Iter Number             Power1  Speed1  \
# 0      first name: Person  last name: Human  date: end of time     NaN
# 2                Row Type       Iter Number             Power1  Speed1
# 3                    Iter                 1                360     108
# 4                    Iter                 2                684     508
# 5                    Iter                 3                365     126
# ...                   ...               ...                ...     ...
# 76372                Iter                 6                879      73
# 76373             Average               979                641     531
# 76374             Maximum               783                172     941
# 76375            Std.Dev.               221                112     717
# 76376               Total               429                  -       -
#
#        Speed2  Electricity  Effort  Weight  Torque  Iteration
# 0         NaN          NaN     NaN     NaN     NaN          1
# 2      Speed2  Electricity  Effort  Weight  Torque          1
# 3         863          599     680     442     982          1
# 4         613          241     249     758     639          1
# 5         825          407     855     164      86          1
# ...       ...          ...     ...     ...     ...        ...
# 76372     977          680     500     395     863       5994
# 76373     374          448     407     185     439       5994
# 76374      53          982     217     963     502       5994
# 76375     630          239     561     142     909       5994
# 76376       -            -     847     583     407       5994
#
# [58397 rows x 10 columns]

# %%
# view current variables
# %who_ls
# Out:
# ['close',
#  'column_values',
#  'counter',
#  'data_import',
#  'drop_extra',
#  'drop_nans',
#  'i',
#  'iter_cols',
#  'os',
#  'pd',
#  'pwd']

# %%
# set rows displayed
pd.set_option('display.max_rows', 500)
iter_cols.head(500)
# Out:
#                Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0    first name: Person  last name: Human  date: end of time     NaN     NaN
# 2              Row Type       Iter Number             Power1  Speed1  Speed2
# 3                  Iter                 1                360     108     863
# 4                  Iter                 2                684     508     613
# 5                  Iter                 3                365     126     825
# 6                  Iter                 4                764     594     304
# 7                  Iter                 5                487      97     593
# 8               Average               182                361     741     231
# 9               Maximum               276                 33      97     154
# 10             Std.Dev.               523               1000      34     904
# 11                Total               336                  -       -       -
# 14   first name: Person  last name: Human  date: end of time     NaN     NaN
# 16             Row Type       Iter Number             Power1  Speed1  Speed2
# 17                 Iter                 1                702     494     311
# 18                 Iter                 2                929      82     838
# 19                 Iter                 3                763     402     344
# 20                 Iter                 4                469     930     560
# 21                 Iter                 5                688     145      41
# 22              Average                66                307     835     615
# 23              Maximum               329                402     777     664
# 24             Std.Dev.               439                770     222     395
# 25                Total               287                  -       -       -
# 28   first name: Person  last name: Human  date: end of time     NaN     NaN
# 30             Row Type       Iter Number             Power1  Speed1  Speed2
# 31                 Iter                 1                618     728     829
# 32                 Iter                 2                191     887     652
# 33                 Iter                 3                288     352     434
# 34                 Iter                 4                443     421     954
# 35                 Iter                 5                452     430      57
# 36              Average               769                535     217     840
# 37              Maximum               317                573     326     989
# 38             Std.Dev.                52                 27      49     696
# 39                Total                98                  -       -       -
# 42   first name: Person  last name: Human  date: end of time     NaN     NaN
# 44             Row Type       Iter Number             Power1  Speed1  Speed2
# 45                 Iter                 1                372     592     393
# 46                 Iter                 2                546     679     734
# 47                 Iter                 3                  2     357     301
# 48                 Iter                 4                474      41      57
# 49                 Iter                 5                715     278     862
# 50              Average               707                221      80     972
# 51              Maximum               743                163     548     844
# 52             Std.Dev.               855                207     917     763
# 53                Total               948                  -       -       -
# 56   first name: Person  last name: Human  date: end of time     NaN     NaN
# 58             Row Type       Iter Number             Power1  Speed1  Speed2
# 59                 Iter                 1                146     596     946
# 60                 Iter                 2                452     547     999
# 61                 Iter                 3                506     788     308
# 62              Average                74                892     812     719
# 63              Maximum               858                783     621     778
# 64             Std.Dev.               268                979      93      58
# 65                Total               162                  -       -       -
# 68   first name: Person  last name: Human  date: end of time     NaN     NaN
# 70             Row Type       Iter Number             Power1  Speed1  Speed2
# 71                 Iter                 1                504     517     395
# 72                 Iter                 2                 24     561     908
# 73                 Iter                 3                201     913      64
# 74              Average               643                957     954     679
# 75              Maximum               493                118     807      95
# 76             Std.Dev.               341                337     994     117
# 77                Total               460                  -       -       -
# 80   first name: Person  last name: Human  date: end of time     NaN     NaN
# 82             Row Type       Iter Number             Power1  Speed1  Speed2
# 83                 Iter                 1                779     504     574
# 84                 Iter                 2                713     720     952
# 85                 Iter                 3                677      19      35
# 86              Average                38                470     883     277
# 87              Maximum               658                822     763     466
# 88             Std.Dev.               629                262     432     136
# 89                Total               731                  -       -       -
# 92   first name: Person  last name: Human  date: end of time     NaN     NaN
# 94             Row Type       Iter Number             Power1  Speed1  Speed2
# 95                 Iter                 1                682     247     118
# 96                 Iter                 2                943     660     269
# 97                 Iter                 3                717     906      23
# 98              Average               618                413     312     716
# 99              Maximum               525                111     737     378
# 100            Std.Dev.               858                824      84     214
# 101               Total                54                  -       -       -
# 104  first name: Person  last name: Human  date: end of time     NaN     NaN
# 106            Row Type       Iter Number             Power1  Speed1  Speed2
# 107                Iter                 1                810      75     476
# 108                Iter                 2                709     672     851
# 109                Iter                 3                506     600     718
# 110             Average               815                230     350     286
# 111             Maximum               719                 94     976     616
# 112            Std.Dev.                57                950     576     163
# 113               Total               133                  -       -       -
# 116  first name: Person  last name: Human  date: end of time     NaN     NaN
# 118            Row Type       Iter Number             Power1  Speed1  Speed2
# 119                Iter                 1                 29     327     220
# 120                Iter                 2                959     105     886
# 121                Iter                 3                520     154     303
# 122             Average               499                 48     999     923
# 123             Maximum               284                753     380     380
# 124            Std.Dev.               663                988     724     721
# 125               Total               141                  -       -       -
# 128  first name: Person  last name: Human  date: end of time     NaN     NaN
# 130            Row Type       Iter Number             Power1  Speed1  Speed2
# 131                Iter                 1                180     410     106
# 132                Iter                 2                667     248     266
# 133                Iter                 3                304     362     768
# 134             Average               960                658     145     157
# 135             Maximum               319                936     526     631
# 136            Std.Dev.               967                306     607     193
# 137               Total               534                  -       -       -
# 140  first name: Person  last name: Human  date: end of time     NaN     NaN
# 142            Row Type       Iter Number             Power1  Speed1  Speed2
# 143                Iter                 1                 35     369     169
# 144                Iter                 2                211     225     890
# 145                Iter                 3                858     787      10
# 146             Average               260                405     307      15
# 147             Maximum               509                964     461     176
# 148            Std.Dev.               911                334      67     205
# 149               Total               434                  -       -       -
# 152  first name: Person  last name: Human  date: end of time     NaN     NaN
# 154            Row Type       Iter Number             Power1  Speed1  Speed2
# 155                Iter                 1                897      26     926
# 156                Iter                 2                808     779     906
# 157                Iter                 3                198     808     788
# 158             Average               685                702      66     996
# 159             Maximum               933                834     612      68
# 160            Std.Dev.               216                935      21     255
# 161               Total               542                  -       -       -
# 164  first name: Person  last name: Human  date: end of time     NaN     NaN
# 166            Row Type       Iter Number             Power1  Speed1  Speed2
# 167                Iter                 1                695     228     331
# 168                Iter                 2                168     107     319
# 169                Iter                 3                977     509     598
# 170                Iter                 4                527     824     210
# 171             Average               642                757     335     460
# 172             Maximum               860                760     338     513
# 173            Std.Dev.               476                178     727     605
# 174               Total               112                  -       -       -
# 177  first name: Person  last name: Human  date: end of time     NaN     NaN
# 179            Row Type       Iter Number             Power1  Speed1  Speed2
# 180                Iter                 1                638     914     568
# 181                Iter                 2                422     908     482
# 182                Iter                 3                186     401     665
# 183             Average               487                631     880     448
# 184             Maximum               188                478     209     787
# 185            Std.Dev.               869                456     671     542
# 186               Total               650                  -       -       -
# 189  first name: Person  last name: Human  date: end of time     NaN     NaN
# 191            Row Type       Iter Number             Power1  Speed1  Speed2
# 192                Iter                 1                580     688     751
# 193                Iter                 2                909     994     946
# 194                Iter                 3                393     408     700
# 195             Average               966                426     467     680
# 196             Maximum               944                975     418     492
# 197            Std.Dev.               845                805      86     838
# 198               Total               301                  -       -       -
# 201  first name: Person  last name: Human  date: end of time     NaN     NaN
# 203            Row Type       Iter Number             Power1  Speed1  Speed2
# 204                Iter                 1                782      56     539
# 205                Iter                 2                567     539      29
# 206                Iter                 3                285     408     700
# 207             Average               650                387     270     332
# 208             Maximum               959                191     795     783
# 209            Std.Dev.               220                826     774     574
# 210               Total               289                  -       -       -
# 213  first name: Person  last name: Human  date: end of time     NaN     NaN
# 215            Row Type       Iter Number             Power1  Speed1  Speed2
# 216                Iter                 1                656      27     127
# 217                Iter                 2                513     482     656
# 218                Iter                 3                 48     327     229
# 219                Iter                 4                502     249     503
# 220                Iter                 5                754     875     628
# 221                Iter                 6                 73     185     274
# 222             Average               994                909     704     364
# 223             Maximum               893                 56      99     136
# 224            Std.Dev.               259                555     238     218
# 225               Total               591                  -       -       -
# 228  first name: Person  last name: Human  date: end of time     NaN     NaN
# 230            Row Type       Iter Number             Power1  Speed1  Speed2
# 231                Iter                 1                600     725     964
# 232                Iter                 2                298     245     711
# 233                Iter                 3                196     488     761
# 234                Iter                 4                129     756     378
# 235                Iter                 5                200     932     266
# 236                Iter                 6                786     937     499
# 237             Average               360                648     373     811
# 238             Maximum               568                379     775     846
# 239            Std.Dev.               987                260     761     108
# 240               Total                64                  -       -       -
# 243  first name: Person  last name: Human  date: end of time     NaN     NaN
# 245            Row Type       Iter Number             Power1  Speed1  Speed2
# 246                Iter                 1                272     462     430
# 247                Iter                 2                399     846     367
# 248                Iter                 3                 77     564     687
# 249                Iter                 4                271     794     250
# 250             Average               606                788     753     895
# 251             Maximum               424                147     385     728
# 252            Std.Dev.               433                463      35     657
# 253               Total               398                  -       -       -
# 256  first name: Person  last name: Human  date: end of time     NaN     NaN
# 258            Row Type       Iter Number             Power1  Speed1  Speed2
# 259                Iter                 1                549     989     703
# 260                Iter                 2                672     809     267
# 261                Iter                 3                985     226      77
# 262                Iter                 4                645     537     610
# 263             Average               437                104     871     185
# 264             Maximum               185                436     837     664
# 265            Std.Dev.               781                274     842     807
# 266               Total               857                  -       -       -
# 269  first name: Person  last name: Human  date: end of time     NaN     NaN
# 271            Row Type       Iter Number             Power1  Speed1  Speed2
# 272                Iter                 1                583     611     929
# 273                Iter                 2                518     326     285
# 274                Iter                 3                526      46     553
# 275                Iter                 4                619     623     719
# 276             Average               250                570     135     540
# 277             Maximum               121                145     273      24
# 278            Std.Dev.               287                827     716     770
# 279               Total               925                  -       -       -
# 282  first name: Person  last name: Human  date: end of time     NaN     NaN
# 284            Row Type       Iter Number             Power1  Speed1  Speed2
# 285                Iter                 1                973     660     609
# 286                Iter                 2                 61     371     304
# 287                Iter                 3                 63     701      52
# 288             Average               925                684     844     712
# 289             Maximum               745                 87     908     805
# 290            Std.Dev.                97                411     611     584
# 291               Total               540                  -       -       -
# 294  first name: Person  last name: Human  date: end of time     NaN     NaN
# 296            Row Type       Iter Number             Power1  Speed1  Speed2
# 297                Iter                 1                591     292     517
# 298                Iter                 2                194      43     325
# 299                Iter                 3                454     756     534
# 300                Iter                 4                484     956     210
# 301                Iter                 5                540     182     157
# 302             Average               767                913     856     839
# 303             Maximum               325                575     426     456
# 304            Std.Dev.               289                667      15     259
# 305               Total               345                  -       -       -
# 308  first name: Person  last name: Human  date: end of time     NaN     NaN
# 310            Row Type       Iter Number             Power1  Speed1  Speed2
# 311                Iter                 1                415     967     577
# 312                Iter                 2                518      74     611
# 313                Iter                 3                690     682     738
# 314                Iter                 4                340     631      49
# 315                Iter                 5                375     834     351
# 316             Average               547                 90     682     904
# 317             Maximum               866                919      76     669
# 318            Std.Dev.               273                465     658     429
# 319               Total                 5                  -       -       -
# 322  first name: Person  last name: Human  date: end of time     NaN     NaN
# 324            Row Type       Iter Number             Power1  Speed1  Speed2
# 325                Iter                 1                415     671     909
# 326                Iter                 2                706     309     832
# 327                Iter                 3                750      79     803
# 328                Iter                 4                695     976     552
# 329                Iter                 5                560     166     913
# 330                Iter                 6                642     848     510
# 331             Average               595                630      34     225
# 332             Maximum               956                 30     829     236
# 333            Std.Dev.               859                512     424     351
# 334               Total                51                  -       -       -
# 337  first name: Person  last name: Human  date: end of time     NaN     NaN
# 339            Row Type       Iter Number             Power1  Speed1  Speed2
# 340                Iter                 1                179     223     323
# 341                Iter                 2                612     696     783
# 342                Iter                 3               1000     926     369
# 343                Iter                 4                308     709     149
# 344                Iter                 5                345     566     470
# 345                Iter                 6                474     537     436
# 346             Average               966                324     591     772
# 347             Maximum               192                405     474     841
# 348            Std.Dev.               530                406     424     360
# 349               Total               726                  -       -       -
# 352  first name: Person  last name: Human  date: end of time     NaN     NaN
# 354            Row Type       Iter Number             Power1  Speed1  Speed2
# 355                Iter                 1                883     752     258
# 356                Iter                 2                638     615     985
# 357                Iter                 3                492     561     955
# 358                Iter                 4                802     185     921
# 359             Average                27                515     501      87
# 360             Maximum               752                586     716     521
# 361            Std.Dev.               623                849     619      94
# 362               Total               883                  -       -       -
# 365  first name: Person  last name: Human  date: end of time     NaN     NaN
# 367            Row Type       Iter Number             Power1  Speed1  Speed2
# 368                Iter                 1                206      40     866
# 369                Iter                 2                536     630     381
# 370                Iter                 3                 75     714     472
# 371                Iter                 4                659      76     880
# 372             Average               173                920     660     766
# 373             Maximum               152                725     522     137
# 374            Std.Dev.               664                713     639     445
# 375               Total               734                  -       -       -
# 378  first name: Person  last name: Human  date: end of time     NaN     NaN
# 380            Row Type       Iter Number             Power1  Speed1  Speed2
# 381                Iter                 1                250     229     894
# 382                Iter                 2                751     943     101
# 383                Iter                 3                631     976     308
# 384                Iter                 4                 16     493     215
# 385             Average                67                569     411     647
# 386             Maximum               846                637     266     599
# 387            Std.Dev.                52                  9     170      69
# 388               Total               946                  -       -       -
# 391  first name: Person  last name: Human  date: end of time     NaN     NaN
# 393            Row Type       Iter Number             Power1  Speed1  Speed2
# 394                Iter                 1                828     512     244
# 395                Iter                 2                643      76      39
# 396                Iter                 3                713     518     444
# 397                Iter                 4                890     871     702
# 398             Average               419                 18     258     506
# 399             Maximum               422                517     374     113
# 400            Std.Dev.               948                 48     335       6
# 401               Total               532                  -       -       -
# 404  first name: Person  last name: Human  date: end of time     NaN     NaN
# 406            Row Type       Iter Number             Power1  Speed1  Speed2
# 407                Iter                 1                649     258     167
# 408                Iter                 2                223     484     692
# 409                Iter                 3                927     762     465
# 410                Iter                 4                129     937     665
# 411             Average               376                344     576     420
# 412             Maximum               201                187     797     873
# 413            Std.Dev.               566                187     576     711
# 414               Total               610                  -       -       -
# 417  first name: Person  last name: Human  date: end of time     NaN     NaN
# 419            Row Type       Iter Number             Power1  Speed1  Speed2
# 420                Iter                 1                511     385     665
# 421                Iter                 2                148     880     951
# 422                Iter                 3                560     777     922
# 423                Iter                 4                335     532     319
# 424             Average               904                468     791     231
# 425             Maximum               771                 97     495     549
# 426            Std.Dev.               935                259     932     367
# 427               Total               232                  -       -       -
# 430  first name: Person  last name: Human  date: end of time     NaN     NaN
# 432            Row Type       Iter Number             Power1  Speed1  Speed2
# 433                Iter                 1                 42     284     948
# 434                Iter                 2                789     444     911
# 435                Iter                 3                529     644     626
# 436                Iter                 4                361     869     325
# 437                Iter                 5                511     477     885
# 438             Average               732                 61     351     818
# 439             Maximum                67                938     836     252
# 440            Std.Dev.               115                147     195     412
# 441               Total               473                  -       -       -
# 444  first name: Person  last name: Human  date: end of time     NaN     NaN
# 446            Row Type       Iter Number             Power1  Speed1  Speed2
# 447                Iter                 1                 13     867     974
# 448                Iter                 2                674     598     636
# 449                Iter                 3                923      64     699
# 450                Iter                 4                221     638     907
# 451                Iter                 5                737     712      77
# 452                Iter                 6                928     785     794
# 453             Average               154                 41     279     468
# 454             Maximum               298                173     619     798
# 455            Std.Dev.               350                798     173     460
# 456               Total               758                  -       -       -
# 459  first name: Person  last name: Human  date: end of time     NaN     NaN
# 461            Row Type       Iter Number             Power1  Speed1  Speed2
# 462                Iter                 1                192     982     283
# 463                Iter                 2                824     615     972
# 464                Iter                 3                 60      77     543
# 465                Iter                 4                930     537     489
# 466                Iter                 5                359     359     604
# 467             Average               883                545     808     600
# 468             Maximum               647                566     488     148
# 469            Std.Dev.                44                589     712     772
# 470               Total               603                  -       -       -
# 473  first name: Person  last name: Human  date: end of time     NaN     NaN
# 475            Row Type       Iter Number             Power1  Speed1  Speed2
# 476                Iter                 1                313     808     940
# 477                Iter                 2                643     193      15
# 478                Iter                 3                996     260     132
# 479                Iter                 4                130     841     980
# 480                Iter                 5                572     448     383
# 481             Average               275                397     561     891
# 482             Maximum               381                 48     637     914
# 483            Std.Dev.               545                232     703     800
# 484               Total               797                  -       -       -
# 487  first name: Person  last name: Human  date: end of time     NaN     NaN
# 489            Row Type       Iter Number             Power1  Speed1  Speed2
# 490                Iter                 1                984     275      46
# 491                Iter                 2                693     618     797
# 492                Iter                 3                 39     953     411
# 493                Iter                 4                223     368     466
# 494                Iter                 5                559     406     367
# 495             Average               859                327     380     485
# 496             Maximum               730                460     744      11
# 497            Std.Dev.               674                351     808     811
# 498               Total               343                  -       -       -
# 501  first name: Person  last name: Human  date: end of time     NaN     NaN
# 503            Row Type       Iter Number             Power1  Speed1  Speed2
# 504                Iter                 1                 89     178      99
# 505                Iter                 2                678     688     363
# 506                Iter                 3                264     676     982
# 507                Iter                 4                182     472     943
# 508                Iter                 5                539      89     538
# 509             Average               948                488     226     783
# 510             Maximum                30                 63     585     257
# 511            Std.Dev.               417                770     574     897
# 512               Total               151                  -       -       -
# 515  first name: Person  last name: Human  date: end of time     NaN     NaN
# 517            Row Type       Iter Number             Power1  Speed1  Speed2
# 518                Iter                 1                564     279     771
# 519                Iter                 2                184      84     730
# 520                Iter                 3                681     947      24
# 521                Iter                 4                634     782      57
# 522                Iter                 5                789     506     669
# 523             Average                85                432     986     422
# 524             Maximum               472                340     385     267
# 525            Std.Dev.               668                498     321     213
# 526               Total               219                  -       -       -
# 529  first name: Person  last name: Human  date: end of time     NaN     NaN
# 531            Row Type       Iter Number             Power1  Speed1  Speed2
# 532                Iter                 1                992     617     267
# 533                Iter                 2                538     877     904
# 534                Iter                 3                379     865     511
# 535                Iter                 4                853     349     298
# 536                Iter                 5                 47     683      47
# 537             Average               647                904     350     786
# 538             Maximum               790                149      56     583
# 539            Std.Dev.               207                285     760     248
# 540               Total               662                  -       -       -
# 543  first name: Person  last name: Human  date: end of time     NaN     NaN
# 545            Row Type       Iter Number             Power1  Speed1  Speed2
# 546                Iter                 1                826     248     626
# 547             Average               234                355     322     958
# 548             Maximum               569                716     122     528
# 549            Std.Dev.               141                904       3     120
# 550               Total               374                  -       -       -
# 553  first name: Person  last name: Human  date: end of time     NaN     NaN
# 555            Row Type       Iter Number             Power1  Speed1  Speed2
# 556                Iter                 1                 52     216     253
# 557                Iter                 2                752     484     997
# 558                Iter                 3                803     130     149
# 559             Average               340                223     352     371
# 560             Maximum               324                816     194     324
# 561            Std.Dev.               125                507     113     292
# 562               Total               617                  -       -       -
# 565  first name: Person  last name: Human  date: end of time     NaN     NaN
# 567            Row Type       Iter Number             Power1  Speed1  Speed2
# 568                Iter                 1                946      24     962
# 569             Average               537                466     178     647
# 570             Maximum               220                104      34     891
# 571            Std.Dev.               227                863     994      33
# 572               Total               707                  -       -       -
# 575  first name: Person  last name: Human  date: end of time     NaN     NaN
# 577            Row Type       Iter Number             Power1  Speed1  Speed2
# 578                Iter                 1                802     410     197
# 579             Average               769                844     737     837
# 580             Maximum               829                216     580     190
# 581            Std.Dev.               627                 47     215     339
# 582               Total               882                  -       -       -
# 585  first name: Person  last name: Human  date: end of time     NaN     NaN
# 587            Row Type       Iter Number             Power1  Speed1  Speed2
# 588                Iter                 1                921      33     559
# 589             Average               679                490     978     669
# 590             Maximum               413                  8     908     525
# 591            Std.Dev.               823                767     904     580
# 592               Total               582                  -       -       -
# 595  first name: Person  last name: Human  date: end of time     NaN     NaN
# 597            Row Type       Iter Number             Power1  Speed1  Speed2
# 598                Iter                 1                998     958     763
# 599                Iter                 2                713     797     716
# 600                Iter                 3                337     575     669
# 601             Average               278                498     621     334
# 602             Maximum               655                404     972     518
# 603            Std.Dev.               162                633     103     346
# 604               Total               210                  -       -       -
# 607  first name: Person  last name: Human  date: end of time     NaN     NaN
# 609            Row Type       Iter Number             Power1  Speed1  Speed2
# 610                Iter                 1                275     823     854
# 611                Iter                 2                552     112     451
# 612                Iter                 3                 19     990     997
# 613                Iter                 4                293     254     845
# 614             Average                82                954     307      81
# 615             Maximum               499                600     366     863
# 616            Std.Dev.               273                 66     651     902
# 617               Total               725                  -       -       -
# 620  first name: Person  last name: Human  date: end of time     NaN     NaN
# 622            Row Type       Iter Number             Power1  Speed1  Speed2
# 623                Iter                 1                236     194     496
# 624                Iter                 2                294     284     352
# 625                Iter                 3                217     993     111
# 626                Iter                 4                721     269     853
# 627                Iter                 5                447     750     891
# 628             Average               282                427     735     516
# 629             Maximum               363                196     346     706
# 630            Std.Dev.               604                985     288     418
# 631               Total               929                  -       -       -
# 634  first name: Person  last name: Human  date: end of time     NaN     NaN
# 636            Row Type       Iter Number             Power1  Speed1  Speed2
# 637                Iter                 1                439     596     777
# 638                Iter                 2                774     796      99
# 639                Iter                 3                 17     312     730
# 640                Iter                 4                984     252     182
# 641             Average               448                948     912     524
# 642             Maximum                18                744     490     533
# 643            Std.Dev.               804                 44     781     435
# 644               Total               963                  -       -       -
# 647  first name: Person  last name: Human  date: end of time     NaN     NaN
# 649            Row Type       Iter Number             Power1  Speed1  Speed2
# 650                Iter                 1                682     722     883
#
#      Electricity  Effort  Weight  Torque  Iteration
# 0            NaN     NaN     NaN     NaN          1
# 2    Electricity  Effort  Weight  Torque          1
# 3            599     680     442     982          1
# 4            241     249     758     639          1
# 5            407     855     164      86          1
# 6            718     278     674     774          1
# 7            206     779     800     123          1
# 8            731     493     847     237          1
# 9             25     922       9     312          1
# 10           237     600     170     553          1
# 11             -     977     744     652          1
# 14           NaN     NaN     NaN     NaN          2
# 16   Electricity  Effort  Weight  Torque          2
# 17           492     456     370     150          2
# 18           421     154     346     227          2
# 19           951     139     295     285          2
# 20           395     433     237     429          2
# 21           188     534     778     152          2
# 22           731     943     460      76          2
# 23            98      44     932     409          2
# 24             3      97     802     570          2
# 25             -     655     169     620          2
# 28           NaN     NaN     NaN     NaN          3
# 30   Electricity  Effort  Weight  Torque          3
# 31           925     777     943     412          3
# 32           255     214      42     343          3
# 33           960     106     326     797          3
# 34           550     113     867     705          3
# 35           115     680     449     146          3
# 36           172     474     424     189          3
# 37           867     686     559     169          3
# 38           249     886     175     218          3
# 39             -      40     686     585          3
# 42           NaN     NaN     NaN     NaN          4
# 44   Electricity  Effort  Weight  Torque          4
# 45           453     624      34     334          4
# 46           612     382     917     920          4
# 47           139     935     722     996          4
# 48           934     250     801     389          4
# 49           460     377     893      94          4
# 50           152     640      81     430          4
# 51           761     810     776     590          4
# 52           211     831     566     871          4
# 53             -     139     598     821          4
# 56           NaN     NaN     NaN     NaN          5
# 58   Electricity  Effort  Weight  Torque          5
# 59           165     942      39     715          5
# 60           827     103     495     340          5
# 61           197     179     974      44          5
# 62           684     864      86     636          5
# 63           301     107      22     577          5
# 64           305     939     261     250          5
# 65             -     732     801     876          5
# 68           NaN     NaN     NaN     NaN          6
# 70   Electricity  Effort  Weight  Torque          6
# 71           953     582     353     603          6
# 72           650     896     719     714          6
# 73           351     979     571     235          6
# 74           768     665      68     645          6
# 75           905     638     875     963          6
# 76           181     291     792     369          6
# 77             -     167      38     948          6
# 80           NaN     NaN     NaN     NaN          7
# 82   Electricity  Effort  Weight  Torque          7
# 83             5     564     375     604          7
# 84            72     167     208     174          7
# 85           976     274     684     586          7
# 86           258       8     649     615          7
# 87           324     441     570     116          7
# 88           429      83     635     314          7
# 89             -     463     303     413          7
# 92           NaN     NaN     NaN     NaN          8
# 94   Electricity  Effort  Weight  Torque          8
# 95           790     523     377     969          8
# 96           898     607     909     504          8
# 97           752      97     117     329          8
# 98           771     911     355     486          8
# 99           179     613     813     889          8
# 100          190     907     572     707          8
# 101            -      98     515     772          8
# 104          NaN     NaN     NaN     NaN          9
# 106  Electricity  Effort  Weight  Torque          9
# 107          586     712     894     363          9
# 108          934     623     597     557          9
# 109          672     384     601     738          9
# 110          532      72     938     337          9
# 111          553     196      51     215          9
# 112          627     557     701     801          9
# 113            -     680     961     634          9
# 116          NaN     NaN     NaN     NaN         10
# 118  Electricity  Effort  Weight  Torque         10
# 119          939     154     216     399         10
# 120           66     638     352     422         10
# 121          329     522     513     767         10
# 122          597     933     731     533         10
# 123          869     884      52     412         10
# 124          841     907     785     453         10
# 125            -     385     177     982         10
# 128          NaN     NaN     NaN     NaN         11
# 130  Electricity  Effort  Weight  Torque         11
# 131          273      30     348     262         11
# 132          313     836     199     628         11
# 133          137     709     754     173         11
# 134          957     469      14     956         11
# 135          907     241     813      56         11
# 136          578     679     126     807         11
# 137            -      79     729     399         11
# 140          NaN     NaN     NaN     NaN         12
# 142  Electricity  Effort  Weight  Torque         12
# 143            3     161     677     829         12
# 144          434     632     693     541         12
# 145          687     102      22      97         12
# 146           65     811     501     574         12
# 147          384     921     218     632         12
# 148          738     400     263     476         12
# 149            -     832     461     830         12
# 152          NaN     NaN     NaN     NaN         13
# 154  Electricity  Effort  Weight  Torque         13
# 155          827     139     394     583         13
# 156          784     487     432     745         13
# 157          719     612     236     960         13
# 158           14     235     267     468         13
# 159          666     346     961     305         13
# 160          421     412     522     848         13
# 161            -     980     393     679         13
# 164          NaN     NaN     NaN     NaN         14
# 166  Electricity  Effort  Weight  Torque         14
# 167          624     247     708     630         14
# 168          866     544     287     124         14
# 169          432     871     402     511         14
# 170          136     403      34     476         14
# 171          937     764     645     363         14
# 172          548     411     493      99         14
# 173          850     907     796     970         14
# 174            -     708     851      16         14
# 177          NaN     NaN     NaN     NaN         15
# 179  Electricity  Effort  Weight  Torque         15
# 180          544     993     840     210         15
# 181          995     624     924     394         15
# 182          750     822     613     824         15
# 183          212     905     960     927         15
# 184          869     712       9     353         15
# 185          200     828     505     594         15
# 186            -     536     107      46         15
# 189          NaN     NaN     NaN     NaN         16
# ...
# 265          569     397     931     566         21
# 266            -     897     958     607         21
# 269          NaN     NaN     NaN     NaN         22
# 271  Electricity  Effort  Weight  Torque         22
# 272          156      84      21     233         22
# 273          503      36     785     412         22
# 274          991     852     921     554         22
# 275          614     159     680     567         22
# 276          143      53     166     260         22
# 277          199      88     188     185         22
# 278          644     447     722     265         22
# 279            -     282     290     892         22
# 282          NaN     NaN     NaN     NaN         23
# 284  Electricity  Effort  Weight  Torque         23
# 285          932     479     623     432         23
# 286          991     990     630     763         23
# 287          535     671     598     372         23
# 288          172     388     167     980         23
# 289          499     430     405      38         23
# 290          220     791     353     704         23
# 291            -     784     871     554         23
# 294          NaN     NaN     NaN     NaN         24
# 296  Electricity  Effort  Weight  Torque         24
# 297          237     265     891     256         24
# 298          481     536     601     532         24
# 299          616     226     732     742         24
# 300          381     613     651     344         24
# 301          721     144     252     483         24
# 302          966     968     265     527         24
# 303          895     736     927     986         24
# 304          594      77     655     775         24
# 305            -     449     673     483         24
# 308          NaN     NaN     NaN     NaN         25
# 310  Electricity  Effort  Weight  Torque         25
# 311          225      29     473     945         25
# 312          250     990     895     593         25
# 313          344     457      73     898         25
# 314          827     749     575     820         25
# 315          708     642     788      35         25
# 316          131     111     849     756         25
# 317          106     124     529      85         25
# 318          553     857       9     299         25
# 319            -     579     732     405         25
# 322          NaN     NaN     NaN     NaN         26
# 324  Electricity  Effort  Weight  Torque         26
# 325          217     492     585     453         26
# 326          613     713     828      75         26
# 327          698     474     594      38         26
# 328          631     957     308     928         26
# 329          747     710      64     513         26
# 330           11     759     909     779         26
# 331           40     780      89      31         26
# 332           28      35     719     618         26
# 333          577     220     639     178         26
# 334            -     704      16     843         26
# 337          NaN     NaN     NaN     NaN         27
# 339  Electricity  Effort  Weight  Torque         27
# 340          439     994     486     588         27
# 341          726     121     801     181         27
# 342          464     356     972     140         27
# 343          940     773     639     574         27
# 344          934     837     351     272         27
# 345          372      20     671     289         27
# 346          124     199     990      48         27
# 347           56     456     329     550         27
# 348          507     119     627     127         27
# 349            -      28     321     935         27
# 352          NaN     NaN     NaN     NaN         28
# 354  Electricity  Effort  Weight  Torque         28
# 355          115     720     722     831         28
# 356          713     350     805     287         28
# 357          303     146     236     602         28
# 358          651     513     210     727         28
# 359          988     777     242     224         28
# 360          761     906      30     299         28
# 361          566     530     709     411         28
# 362            -     256     224     331         28
# 365          NaN     NaN     NaN     NaN         29
# 367  Electricity  Effort  Weight  Torque         29
# 368          739     530     959     449         29
# 369          724     380     884     495         29
# 370          692     715      49     717         29
# 371          269     786     720     956         29
# 372          726      49     671     610         29
# 373          877     305     782     751         29
# 374          451     786      90     600         29
# 375            -     649     292     411         29
# 378          NaN     NaN     NaN     NaN         30
# 380  Electricity  Effort  Weight  Torque         30
# 381          249     886     371     572         30
# 382          947     524     929       5         30
# 383          185     376     888     734         30
# 384          342      54     887     924         30
# 385          360     644     736     552         30
# 386           84     276     680     790         30
# 387          934     666     467     241         30
# 388            -     878     642    1000         30
# 391          NaN     NaN     NaN     NaN         31
# 393  Electricity  Effort  Weight  Torque         31
# 394          452     227     679     495         31
# 395          932     128     799      12         31
# 396           95     898     788     553         31
# 397          179     382     570     680         31
# 398          303     699     455     828         31
# 399          704     535     972     359         31
# 400          221      80     981     719         31
# 401            -     743      31     855         31
# 404          NaN     NaN     NaN     NaN         32
# 406  Electricity  Effort  Weight  Torque         32
# 407          706     219     686     898         32
# 408          710     540     409     340         32
# 409          793     239     113      80         32
# 410          689     199      32     938         32
# 411          839     507     235      41         32
# 412          489      55      71     623         32
# 413          918     572     421     360         32
# 414            -     356      88      23         32
# 417          NaN     NaN     NaN     NaN         33
# 419  Electricity  Effort  Weight  Torque         33
# 420          782     198      88     675         33
# 421          166     537     141     871         33
# 422          509     668     454     948         33
# 423          128     316     785      25         33
# 424          103     826     740      12         33
# 425          464     495     748     348         33
# 426          367     285     898     675         33
# 427            -     160     602     869         33
# 430          NaN     NaN     NaN     NaN         34
# 432  Electricity  Effort  Weight  Torque         34
# 433          181     682     344     526         34
# 434          385     762     923     840         34
# 435          398     727     179     942         34
# 436           96     306      77     234         34
# 437          185     658     347     168         34
# 438          870     686     160     521         34
# 439           12     917     901     496         34
# 440          384     760      37     521         34
# 441            -     204     677     974         34
# 444          NaN     NaN     NaN     NaN         35
# 446  Electricity  Effort  Weight  Torque         35
# 447          211      71     308     153         35
# 448          423     116     146     824         35
# 449          594     680     312     764         35
# 450          153     295     430     596         35
# 451          750     458     115     346         35
# 452          236     822     956     346         35
# 453          827     473     646     115         35
# 454          879      62      11     519         35
# 455          220     299     451     447         35
# 456            -     490     737     928         35
# 459          NaN     NaN     NaN     NaN         36
# 461  Electricity  Effort  Weight  Torque         36
# 462          839     174     374     503         36
# 463          329     584     922     179         36
# 464          926     867     797     396         36
# 465          464     346     684     343         36
# 466          629     746     826     677         36
# 467          964     627     121     789         36
# 468          937     719     721     861         36
# 469          843      34     263     970         36
# 470            -     630     310     866         36
# 473          NaN     NaN     NaN     NaN         37
# 475  Electricity  Effort  Weight  Torque         37
# 476          853     525     320     917         37
# 477          262     822     919     669         37
# 478          904     122     333     458         37
# 479          632     832     449     739         37
# 480          730     891      69     612         37
# 481          698     911     283     635         37
# 482          360     481     419     935         37
# 483          334     114     137     577         37
# 484            -     298     632     552         37
# 487          NaN     NaN     NaN     NaN         38
# 489  Electricity  Effort  Weight  Torque         38
# 490          289     508     241     843         38
# 491          192      44     697     564         38
# 492            3     217     818     977         38
# 493          760     724     825     573         38
# 494          826     148     374     950         38
# 495          477     396     352     842         38
# 496           41     149     439     962         38
# 497          111     790     553     369         38
# 498            -     546     666     311         38
# 501          NaN     NaN     NaN     NaN         39
# 503  Electricity  Effort  Weight  Torque         39
# 504          973     965     509     665         39
# 505          453     340     987     120         39
# 506          329     977      96     735         39
# 507           66     248     157     171         39
# 508          316     453     225     325         39
# 509          120     814     348     880         39
# 510          974     559     986      93         39
# 511          256     466     588     987         39
# 512            -     961     776     485         39
# 515          NaN     NaN     NaN     NaN         40
# 517  Electricity  Effort  Weight  Torque         40
# 518          852     830     438      81         40
# 519          733     619     911     602         40
# 520          828     746     580     687         40
# 521          866     227     733      63         40
# 522          839     186     719     922         40
# 523          723     657     782     805         40
# 524          285     358     665     374         40
# 525          507     761     558     206         40
# 526            -     809     925     317         40
# 529          NaN     NaN     NaN     NaN         41
# 531  Electricity  Effort  Weight  Torque         41
# 532          354     469     225     134         41
# 533          317     587      36     895         41
# 534          693     719     744     147         41
# 535          116     704      91     674         41
# 536          531     385     584     679         41
# 537          645     952     937     874         41
# 538          773     926     672     828         41
# 539          835     169     572     369         41
# 540            -     792      28     265         41
# 543          NaN     NaN     NaN     NaN         42
# 545  Electricity  Effort  Weight  Torque         42
# 546          282     976      90       2         42
# 547          528     615     233     643         42
# 548          129     405     633     348         42
# 549          473     511     847     233         42
# 550            -     307     656     922         42
# 553          NaN     NaN     NaN     NaN         43
# 555  Electricity  Effort  Weight  Torque         43
# 556          146     532     827      28         43
# 557          934     384     696     239         43
# 558          501     238     912     815         43
# 559          520      76     372     860         43
# 560          292      76     803     531         43
# 561          349     708     506      92         43
# 562            -     306     581     233         43
# 565          NaN     NaN     NaN     NaN         44
# 567  Electricity  Effort  Weight  Torque         44
# 568          588      30     158     465         44
# 569          437     491     389     977         44
# 570          612     990     896     666         44
# 571          979     532     269     211         44
# 572            -     580     288     981         44
# 575          NaN     NaN     NaN     NaN         45
# 577  Electricity  Effort  Weight  Torque         45
# 578          239     276     369      45         45
# 579          945     671     598     115         45
# 580           97     577     776     724         45
# 581          152     980     883     791         45
# 582            -     324     987     717         45
# 585          NaN     NaN     NaN     NaN         46
# 587  Electricity  Effort  Weight  Torque         46
# 588          992     906     486     535         46
# 589           39     381     221     729         46
# 590          688     777     454     361         46
# 591          451     933     644     708         46
# 592            -     280     788     554         46
# 595          NaN     NaN     NaN     NaN         47
# 597  Electricity  Effort  Weight  Torque         47
# 598          394     144     317     474         47
# 599          275     975      13     644         47
# 600          797     415     271     925         47
# 601          870     260     905     927         47
# 602           97     421     831     366         47
# 603           53     371     254     782         47
# 604            -     487     576     851         47
# 607          NaN     NaN     NaN     NaN         48
# 609  Electricity  Effort  Weight  Torque         48
# 610          626     735     313     557         48
# 611          645     632     871     103         48
# 612          935     176     417     852         48
# 613          169     590     440     264         48
# 614          787     917     114     896         48
# 615          569     592     100     987         48
# 616          274     200     467     484         48
# 617            -      18     376     741         48
# 620          NaN     NaN     NaN     NaN         49
# 622  Electricity  Effort  Weight  Torque         49
# 623          224     445     761     319         49
# 624          668     425     600     188         49
# 625          832     263     108      98         49
# 626           97     542     362     552         49
# 627          645     368     282     778         49
# 628          739     653     615     137         49
# 629          942     671     385     698         49
# 630          871     143     721     666         49
# 631            -     949     309     172         49
# 634          NaN     NaN     NaN     NaN         50
# 636  Electricity  Effort  Weight  Torque         50
# 637          809     818     211      48         50
# 638          547      46     432     811         50
# 639          183     328     785     322         50
# 640          479     429      63     125         50
# 641          513     984      77     780         50
# 642          656     262     774     907         50
# 643          615     685     456     405         50
# 644            -     716     868      18         50
# 647          NaN     NaN     NaN     NaN         51
# 649  Electricity  Effort  Weight  Torque         51
# 650          956     807     667     758         51

# %%
# reset rows displayed
pd.reset_option('all')
# Out:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# C:\Users\jisbe\anaconda3\lib\site-packages\pandas\_config\config.py:622: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
# remove 'index 2' row - unneeded row
drop_extra_columns_name_rows = iter_cols[iter_cols['Row Type'] != 'Row Type']
drop_extra_columns_name_rows
# Out:
#                  Row Type       Iter Number             Power1 Speed1 Speed2  \
# 0      first name: Person  last name: Human  date: end of time    NaN    NaN
# 3                    Iter                 1                360    108    863
# 4                    Iter                 2                684    508    613
# 5                    Iter                 3                365    126    825
# 6                    Iter                 4                764    594    304
# ...                   ...               ...                ...    ...    ...
# 76372                Iter                 6                879     73    977
# 76373             Average               979                641    531    374
# 76374             Maximum               783                172    941     53
# 76375            Std.Dev.               221                112    717    630
# 76376               Total               429                  -      -      -
#
#       Electricity Effort Weight Torque  Iteration
# 0             NaN    NaN    NaN    NaN          1
# 3             599    680    442    982          1
# 4             241    249    758    639          1
# 5             407    855    164     86          1
# 6             718    278    674    774          1
# ...           ...    ...    ...    ...        ...
# 76372         680    500    395    863       5994
# 76373         448    407    185    439       5994
# 76374         982    217    963    502       5994
# 76375         239    561    142    909       5994
# 76376           -    847    583    407       5994
#
# [52403 rows x 10 columns]

# %%
# seperate columns from data frame, creating a 'name data frame'
name_dataframe = drop_extra_columns_name_rows[drop_extra_columns_name_rows['Row Type'].str.contains('first name')]

# using inplace, the .drop changes will be committed to the dataframe
name_dataframe.drop(columns = ['Speed1', 'Speed2', 'Electricity', 'Effort', 'Weight', 'Torque'], inplace = True)

# create dictionary to change the header names
name_dataframe.rename(columns = {'Row Type': 'First Name', 'Iter Number': 'Last Name', 'Power1': 'Date'}, inplace = True)

# remove 'first name', 'last name', from the values in the rows
# string slicing - take the first few indices of the overall value
name_dataframe['First Name'] = name_dataframe['First Name'].str[12:]  # start at 12 index and take the values after
name_dataframe['Last Name'] = name_dataframe['Last Name'].str[11:] # start at 11 index and take the values after
name_dataframe['Date'] = name_dataframe['Date'].str[6:] # start at 6 index and take the values after

name_dataframe
# Out:
# C:\Users\jisbe\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\jisbe\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-73-82f9be6cb481>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name_dataframe['First Name'] = name_dataframe['First Name'].str[12:]  # start at 12 index and take the values after
# <ipython-input-73-82f9be6cb481>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name_dataframe['Last Name'] = name_dataframe['Last Name'].str[11:] # start at 11 index and take the values after
# <ipython-input-73-82f9be6cb481>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name_dataframe['Date'] = name_dataframe['Date'].str[6:] # start at 6 index and take the values after
#       First Name Last Name         Date  Iteration
# 0         Person     Human  end of time          1
# 14        Person     Human  end of time          2
# 28        Person     Human  end of time          3
# 42        Person     Human  end of time          4
# 56        Person     Human  end of time          5
# ...          ...       ...          ...        ...
# 76309     Person     Human  end of time       5990
# 76322     Person     Human  end of time       5991
# 76336     Person     Human  end of time       5992
# 76350     Person     Human  end of time       5993
# 76364     Person     Human  end of time       5994
#
# [5994 rows x 4 columns]

# %%
# create a new dataframe without all of this first name information - a 'no name dataframe'
# want the complete opposite of the name_dataframe - you can use an inverse opertaor'~' 
# this will pull exact opposite rows from name_dataframe logic
no_name_dataframe = drop_extra_columns_name_rows[~drop_extra_columns_name_rows['Row Type'].str.contains('first name')]
no_name_dataframe
# Out:
#        Row Type Iter Number Power1 Speed1 Speed2 Electricity Effort Weight  \
# 3          Iter           1    360    108    863         599    680    442
# 4          Iter           2    684    508    613         241    249    758
# 5          Iter           3    365    126    825         407    855    164
# 6          Iter           4    764    594    304         718    278    674
# 7          Iter           5    487     97    593         206    779    800
# ...         ...         ...    ...    ...    ...         ...    ...    ...
# 76372      Iter           6    879     73    977         680    500    395
# 76373   Average         979    641    531    374         448    407    185
# 76374   Maximum         783    172    941     53         982    217    963
# 76375  Std.Dev.         221    112    717    630         239    561    142
# 76376     Total         429      -      -      -           -    847    583
#
#       Torque  Iteration
# 3        982          1
# 4        639          1
# 5         86          1
# 6        774          1
# 7        123          1
# ...      ...        ...
# 76372    863       5994
# 76373    439       5994
# 76374    502       5994
# 76375    909       5994
# 76376    407       5994
#
# [46409 rows x 10 columns]

# %%
# merge these two dataframes together
pd.merge(left = name_dataframe, right = no_name_dataframe, how = 'inner', on = 'Iteration')
# Out:
#       First Name Last Name         Date  Iteration  Row Type Iter Number  \
# 0         Person     Human  end of time          1      Iter           1
# 1         Person     Human  end of time          1      Iter           2
# 2         Person     Human  end of time          1      Iter           3
# 3         Person     Human  end of time          1      Iter           4
# 4         Person     Human  end of time          1      Iter           5
# ...          ...       ...          ...        ...       ...         ...
# 46404     Person     Human  end of time       5994      Iter           6
# 46405     Person     Human  end of time       5994   Average         979
# 46406     Person     Human  end of time       5994   Maximum         783
# 46407     Person     Human  end of time       5994  Std.Dev.         221
# 46408     Person     Human  end of time       5994     Total         429
#
#       Power1 Speed1 Speed2 Electricity Effort Weight Torque
# 0        360    108    863         599    680    442    982
# 1        684    508    613         241    249    758    639
# 2        365    126    825         407    855    164     86
# 3        764    594    304         718    278    674    774
# 4        487     97    593         206    779    800    123
# ...      ...    ...    ...         ...    ...    ...    ...
# 46404    879     73    977         680    500    395    863
# 46405    641    531    374         448    407    185    439
# 46406    172    941     53         982    217    963    502
# 46407    112    717    630         239    561    142    909
# 46408      -      -      -           -    847    583    407
#
# [46409 rows x 13 columns]

# %% [markdown]
# # Done!
#
# Each row is a person with their own individual stats
#
# We can drop the Iter Number column if we so choose, and export this into a CSV
